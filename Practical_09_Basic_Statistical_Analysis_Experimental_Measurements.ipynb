# %% [markdown]
# # Practical 9: Basic Statistical Analysis of Experimental Measurements
#
# ### Computer Programming Lab – Chemical Engineering
# **Syllabus Experiment:** **Basic statistical analysis (mean, standard deviation) of experimental measurements**
# **Main Python Library:** `pandas`
# **Environment:** Google Colab / GitHub Codespaces + Jupyter Notebook + GitHub Copilot
#
# ---
#
# ## Important: Exact Syllabus Context
#
# The complete experiment line in the syllabus is:
#
# > **Basic statistical analysis (mean, standard deviation) of experimental measurements**
#
# This practical focuses specifically on **experimental measurements**, with **mean and standard deviation** as the core statistical operations. Pandas will be used to load, inspect, group and summarize the experimental data.
#
# ## How we will use AI Copilot
#
# GitHub Copilot is your AI coding assistant. Use it to understand statistical concepts, Pandas commands, errors and interpretation.
#
# **Do not ask Copilot to write the complete practical at the beginning.** First calculate and interpret the statistics yourself, then use Copilot for hints, explanations and debugging.

# %% [markdown]
# ## 1. Learning Objectives
#
# After completing this practical, you should be able to:
#
# 1. Understand why statistical analysis is important for experimental measurements.
# 2. Calculate the **mean** of experimental measurements.
# 3. Calculate **standard deviation** of experimental measurements.
# 4. Distinguish between mean and standard deviation.
# 5. Use Pandas to calculate descriptive statistics.
# 6. Compare repeated measurements from different experiments or conditions.
# 7. Identify variation in experimental measurements.
# 8. Group experimental data and calculate statistics for each group.
# 9. Use simple visualizations to understand experimental variation.
# 10. Use GitHub Copilot to explain and debug statistical-analysis code.

# %% [markdown]
# ## 2. Chemical Engineering Context
#
# Repeated measurements are common in chemical engineering laboratories. For example, a student may measure:
#
# - temperature several times,
# - pressure several times,
# - concentration several times,
# - pH several times,
# - flow rate several times.
#
# The measurements may not be exactly identical because of instrument limitations, environmental conditions and experimental variation.
#
# Two simple statistics help us describe the measurements:
#
# ### Mean
#
# The mean gives the **average value** of the measurements.
#
# ### Standard deviation
#
# Standard deviation gives an indication of **how much the measurements vary around the mean**.
#
# These statistics do not by themselves prove that an experiment is accurate or scientifically valid; they provide a basic numerical description of the observed measurements.

# %% [markdown]
# ## 3. Activity 1 – Enter Repeated Experimental Measurements
#
# Suppose a student measures the temperature of a laboratory process five times under the same experimental condition.
#
# Use the following teaching data:
#
# ```text
# Temperature (°C): 78.2, 79.1, 78.7, 79.0, 78.5
# ```
#
# Create a Pandas DataFrame containing these observations.

# %%
import pandas as pd

temperature_data = pd.DataFrame({
    'Measurement_No': [1, 2, 3, 4, 5],
    'Temperature_C': [78.2, 79.1, 78.7, 79.0, 78.5]
})

temperature_data

# %% [markdown]
# ### Copilot Activity 1 – Understand the Data
#
# Ask Copilot:
#
# > I am a second-year chemical engineering student. Explain how a Pandas DataFrame can represent repeated experimental measurements. Explain what each row and column represents in my temperature dataset. Do not write additional code.

# %% [markdown]
# ## 4. Activity 2 – Calculate the Mean Manually
#
# Before using Pandas, calculate the mean conceptually.
#
# For measurements `x₁, x₂, ..., xₙ`, the mean is:
#
# **mean = sum of measurements / number of measurements**
#
# For the five temperature measurements, calculate the mean manually and write your answer below.

# %%
# Activity 2
# Calculate the mean using basic Python arithmetic first.

# %% [markdown]
# ### Copilot Activity 2 – Mean
#
# Ask Copilot:
#
# > Explain the meaning of the mean for repeated temperature measurements in a chemical engineering experiment. Explain why the mean is useful but does not tell us how much the measurements vary. Do not write code.

# %% [markdown]
# ## 5. Activity 3 – Mean using Pandas
#
# Now calculate the mean using Pandas.
#
# Investigate:
#
# ```python
# df['Temperature_C'].mean()
# ```
#
# Compare the Pandas result with your manual calculation.

# %%
# Activity 3
# Calculate the mean temperature using Pandas.

# %% [markdown]
# ## 6. Activity 4 – Understand Standard Deviation
#
# Standard deviation describes the spread of measurements around the mean.
#
# Consider two sets of measurements:
#
# **Set A**
#
# ```text
# 78.7, 78.8, 78.7, 78.8, 78.7
# ```
#
# **Set B**
#
# ```text
# 76.0, 81.5, 78.7, 82.0, 74.8
# ```
#
# Both sets are centered around a similar region, but Set B has much greater variation.
#
# ### Think before coding
#
# Which set should have the larger standard deviation? Why?

# %% [markdown]
# ### Copilot Activity 3 – Standard Deviation
#
# Ask Copilot:
#
# > Explain standard deviation to a second-year chemical engineering student using repeated temperature measurements as the example. Explain what a small standard deviation and a large standard deviation mean. Do not use advanced statistical terminology.

# %%
# Activity 4
# Create DataFrames for Set A and Set B and compare their standard deviations.

# %% [markdown]
# ## 7. Activity 5 – Standard Deviation using Pandas
#
# Use Pandas to calculate the standard deviation of the original temperature measurements.
#
# Investigate:
#
# ```python
# df['Temperature_C'].std()
# ```
#
# ### Important Pandas point
#
# Pandas `Series.std()` uses **sample standard deviation** by default (`ddof=1`). For this practical, accept the Pandas default unless the instructor specifically asks you to calculate population standard deviation.
#
# Do not confuse the two definitions. The important programming skill here is knowing what statistical quantity your software function is calculating.

# %%
# Activity 5
# Calculate standard deviation using Pandas.

# %% [markdown]
# ## 8. Activity 6 – Mean and Standard Deviation Together
#
# Create a small summary containing:
#
# - number of measurements
# - mean temperature
# - standard deviation
# - minimum temperature
# - maximum temperature
#
# Use Pandas functions such as:
#
# ```text
# count()
# mean()
# std()
# min()
# max()
# ```
#
# This gives a compact statistical summary of the experimental measurements.

# %%
# Activity 6
# Create a statistical summary for Temperature_C.

# %% [markdown]
# ## 9. Activity 7 – Multiple Experimental Measurements
#
# Now create a more realistic teaching dataset containing repeated measurements of:
#
# - Temperature
# - Pressure
# - Concentration
# - pH
#
# Use at least 8 observations.
#
# Calculate the mean and standard deviation for each measurement variable.

# %%
# Activity 7
# Create a DataFrame containing repeated experimental measurements.

experiment_df = pd.DataFrame({
    'Temperature_C': [78.2, 79.1, 78.7, 79.0, 78.5, 78.8, 79.2, 78.6],
    'Pressure_bar': [2.10, 2.12, 2.08, 2.11, 2.09, 2.13, 2.10, 2.07],
    'Concentration_mol_L': [0.82, 0.80, 0.81, 0.83, 0.79, 0.82, 0.81, 0.80],
    'pH': [6.9, 7.0, 6.8, 7.1, 6.9, 7.0, 6.9, 6.8]
})

experiment_df

# %% [markdown]
# ### Copilot Activity 4 – Multiple Variables
#
# Ask Copilot:
#
# > Explain how Pandas can calculate mean and standard deviation for every numerical column in an experimental DataFrame at once. Explain the purpose of describe() as well. Do not write the complete solution.

# %%
# Calculate mean and standard deviation for all numerical measurements.

# %% [markdown]
# ## 10. Activity 8 – Compare Two Experimental Conditions
#
# Suppose the same measurement was taken under two different experimental conditions.
#
# Create a dataset containing:
#
# - `Condition_A`
# - `Condition_B`
#
# with repeated temperature measurements for each condition.
#
# Calculate the mean and standard deviation for each condition.
#
# ### Interpretation task
#
# Answer:
#
# 1. Which condition has the higher average temperature?
# 2. Which condition has greater variation?
# 3. Is a higher mean automatically better? Why or why not?
#
# Remember: **statistical results need engineering context.**

# %%
# Activity 8
# Compare the mean and standard deviation of two experimental conditions.

# %% [markdown]
# ## 11. Activity 9 – Grouped Statistical Analysis
#
# Create a dataset with an `Experiment_ID` column and repeated temperature measurements for at least three experiments.
#
# Example structure:
#
# | Experiment_ID | Temperature_C |
# |---|---:|
# | EXP001 | 78.2 |
# | EXP001 | 79.1 |
# | EXP001 | 78.7 |
# | EXP002 | 81.2 |
# | EXP002 | 80.8 |
# | ... | ... |
#
# Use Pandas `groupby()` to calculate **mean and standard deviation for each experiment**.
#
# This is a key pattern for real experimental datasets: the same statistical operation can be applied separately to different experimental groups.

# %%
# Activity 9
# Create grouped experimental data and calculate mean and standard deviation by Experiment_ID.

# %% [markdown]
# ## 12. Activity 10 – Detect an Unusual Measurement
#
# Add one deliberately unusual measurement to one experiment.
#
# Recalculate the mean and standard deviation.
#
# Compare the result before and after adding the unusual value.
#
# ### Think
#
# 1. Did the mean change?
# 2. Did the standard deviation change?
# 3. Which statistic appears more sensitive to the unusual measurement?
# 4. Should an unusual measurement automatically be deleted?
#
# **Important:** An unusual experimental value should not automatically be called an error. It may represent a genuine experimental event, instrument problem, transcription error or another cause. It should be investigated before removal.

# %%
# Activity 10
# Add an unusual measurement and compare the statistical summary before and after it.

# %% [markdown]
# ## 13. Activity 11 – Visualize Experimental Variation
#
# Create a simple visualization of repeated measurements.
#
# Use a **box plot** or another suitable plot to compare the distribution of measurements for two or more experimental conditions.
#
# The purpose is to connect numerical statistics with a visual understanding of variation.

# %%
# Activity 11
# Create a simple visualization of experimental measurements.

# %% [markdown]
# ## 14. Copilot Debugging Challenge
#
# The following code contains a common Pandas mistake.
#
# Study it **before** asking Copilot.
#
# ```python
# mean_temp = experiment_df['Temperature_C'].mean
# std_temp = experiment_df['Temperature_C'].std
#
# print('Mean:', mean_temp)
# print('Standard deviation:', std_temp)
# ```
#
# ### Your task
#
# 1. Run the code.
# 2. Look carefully at the output.
# 3. Identify why the output is not the numerical mean and standard deviation.
# 4. Ask Copilot:
#
# > My Pandas code assigns mean and std to variables, but printing them gives a method representation instead of a numerical result. Explain what I forgot and why. Do not rewrite the complete program.
#
# 5. Correct the code yourself.

# %%
# Run the intentionally incorrect code here.
mean_temp = experiment_df['Temperature_C'].mean
std_temp = experiment_df['Temperature_C'].std

print('Mean:', mean_temp)
print('Standard deviation:', std_temp)

# %% [markdown]
# ### Explain the error in your own words
#
# Write your explanation here before continuing.

# %% [markdown]
# ## 15. Final Mini-Project – Experimental Measurement Statistics
#
# Build one clean Pandas-based statistical-analysis workflow.
#
# Your final workflow should:
#
# 1. Load experimental measurements from the CSV created in the previous practical, or create a similar experimental dataset.
# 2. Display the dataset.
# 3. Identify the numerical measurement columns.
# 4. Calculate the **mean** for each measurement.
# 5. Calculate the **standard deviation** for each measurement.
# 6. Calculate minimum and maximum values.
# 7. Group the data by an experimental condition or `Experiment_ID`.
# 8. Calculate mean and standard deviation for each group.
# 9. Add one unusual measurement and observe its effect.
# 10. Create one suitable visualization of the variation.
# 11. Write a short engineering interpretation of the results.
#
# ### Required final interpretation
#
# Do not only display numbers. Write 3–5 sentences explaining:
#
# - which measurement has the greatest variation,
# - which measurement is relatively consistent,
# - what the standard deviation tells you about the repeated measurements,
# - whether any unusual observation requires further investigation.
#
# **Do not claim that a small standard deviation automatically means that an experiment is accurate. Precision/variation and accuracy are different concepts.**

# %%
# FINAL PROJECT
# Experimental Measurement Statistics
# Build your complete Pandas-based statistical workflow here.

# %% [markdown]
# ## 16. Final Copilot Review
#
# After completing your final project, ask Copilot:
#
# > Review my Pandas statistical-analysis workflow for chemical experimental measurements. Check my calculation of mean and standard deviation, grouped analysis, unusual-value comparison, visualization and interpretation. Do not rewrite my notebook; identify possible issues and explain them.
#
# Make changes only after you understand the feedback.

# %% [markdown]
# ## 17. Reflection – What Did You Learn?
#
# Answer in your own words:
#
# 1. What does the mean tell us about repeated experimental measurements?
# 2. What does standard deviation tell us?
# 3. What is the difference between a low and high standard deviation?
# 4. Why can two datasets have similar means but different standard deviations?
# 5. What does Pandas `std()` calculate by default?
# 6. Why is `groupby()` useful for experimental data?
# 7. What happens to the mean and standard deviation when an unusual value is added?
# 8. Why should an unusual measurement not automatically be deleted?
# 9. Why does a small standard deviation not necessarily prove accuracy?
# 10. What did Copilot help you understand or debug?
# 11. Can you explain your statistical-analysis workflow without opening Copilot?

# %% [markdown]
# ## 18. Submission Checklist
#
# - [ ] I created or loaded repeated experimental measurements.
# - [ ] I calculated the mean manually and using Pandas.
# - [ ] I calculated standard deviation using Pandas.
# - [ ] I created a statistical summary.
# - [ ] I analyzed multiple experimental variables.
# - [ ] I compared two experimental conditions.
# - [ ] I performed grouped mean and standard-deviation analysis.
# - [ ] I investigated the effect of an unusual measurement.
# - [ ] I created a visualization of experimental variation.
# - [ ] I completed the Copilot debugging challenge.
# - [ ] I wrote an engineering interpretation of the results.
# - [ ] I used Copilot for explanation and debugging rather than simply copying a complete solution.
# - [ ] I can explain my final analysis.
# - [ ] I saved the completed notebook in my GitHub repository.

# %% [markdown]
# ## 19. Suggested Evaluation – Faculty Use
#
# | Component | Marks |
# |---|---:|
# | Mean calculation and interpretation | 2 |
# | Standard deviation calculation and interpretation | 2 |
# | Pandas-based statistical analysis | 1 |
# | Grouped experimental analysis | 1 |
# | Unusual-value investigation | 1 |
# | Visualization and interpretation | 1 |
# | Copilot usage and debugging | 1 |
# | Student's ability to explain/modify the analysis | 1 |
# | **Total** | **10** |
#
# **Faculty note:** During evaluation, provide a small new set of repeated experimental measurements and ask the student to calculate the mean and standard deviation, explain which dataset is more variable, and modify the code for a second measurement variable.
