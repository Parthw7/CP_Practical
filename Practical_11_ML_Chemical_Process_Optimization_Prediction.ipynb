# %% [markdown]
# # Practical 11: Application of Machine Learning Basics in Chemical Process Optimization and Prediction
#
# ### Computer Programming Lab – Chemical Engineering
# **Syllabus Experiment:** **Application of machine learning basics in chemical process optimization and prediction**
# **Main Python Libraries:** `pandas`, `numpy`, `matplotlib`, `scikit-learn`
# **Environment:** Google Colab / GitHub Codespaces + Jupyter Notebook + GitHub Copilot
#
# ---
#
# ## Important: Exact Syllabus Context
#
# The complete experiment line in the syllabus is:
#
# > **Application of machine learning basics in chemical process optimization and prediction**
#
# This practical introduces students to the **basic ML workflow** through a simple chemical-engineering prediction problem. The objective is not to teach advanced machine learning algorithms, but to let students experience the complete process:
#
# **chemical/process data → prepare data → visualize → train a basic ML model → predict → evaluate → interpret**
#
# ## AI Copilot Approach
#
# GitHub Copilot is used as an AI learning assistant. Students will use it to:
#
# - understand ML concepts,
# - understand scikit-learn functions,
# - generate small code hints,
# - debug errors,
# - interpret model results,
# - suggest improvements.
#
# **Do not ask Copilot to generate the complete ML project.** Students should understand every step of the workflow and be able to explain the final model.

# %% [markdown]
# ## 1. Learning Objectives
#
# After completing this practical, students should be able to:
#
# 1. Understand the basic idea of machine learning in a chemical-engineering context.
# 2. Distinguish between input features and the prediction target.
# 3. Prepare a small process dataset using Pandas.
# 4. Split data into training and testing sets.
# 5. Train a basic regression model using scikit-learn.
# 6. Predict a chemical-process output.
# 7. Evaluate predictions using simple regression metrics.
# 8. Visualize actual and predicted values.
# 9. Use the model to make a simple process prediction.
# 10. Discuss how prediction can support process optimization.
# 11. Use GitHub Copilot to understand and debug an ML workflow.

# %% [markdown]
# ## 2. Chemical Engineering Context
#
# Machine learning can be used in chemical industries for tasks such as:
#
# - predicting product yield,
# - predicting energy consumption,
# - estimating quality parameters,
# - predicting process output from operating conditions,
# - identifying important process variables,
# - supporting process optimization.
#
# In this practical, we will use a **small illustrative dataset** representing a simplified chemical process.
#
# Our goal will be to predict **product yield (%)** from process variables such as:
#
# - temperature,
# - pressure,
# - reaction time,
# - feed concentration.
#
# **Important:** The dataset is created for teaching the programming/ML workflow. It is not a real industrial process model and should not be used for actual process decisions.

# %% [markdown]
# ## 3. Activity 1 – Create the Chemical Process Dataset
#
# Create a Pandas DataFrame containing process measurements.
#
# Columns:
#
# - `Temperature_C`
# - `Pressure_bar`
# - `Reaction_Time_min`
# - `Feed_Concentration_mol_L`
# - `Yield_percent`
#
# `Yield_percent` will be the value that we want the machine-learning model to predict.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

process_df = pd.DataFrame({
    'Temperature_C': [60, 65, 70, 75, 80, 85, 90, 65, 70, 75, 80, 85, 90, 95, 70, 78, 82, 88, 92, 98],
    'Pressure_bar': [1.2, 1.4, 1.5, 1.7, 1.9, 2.1, 2.3, 1.8, 1.6, 2.0, 2.2, 2.4, 2.5, 2.7, 1.9, 2.0, 2.1, 2.3, 2.6, 2.8],
    'Reaction_Time_min': [20, 22, 24, 25, 27, 28, 30, 26, 23, 29, 31, 32, 34, 35, 24, 27, 30, 31, 33, 36],
    'Feed_Concentration_mol_L': [0.80, 0.82, 0.85, 0.88, 0.90, 0.92, 0.95, 0.84, 0.86, 0.89, 0.91, 0.93, 0.96, 0.98, 0.87, 0.90, 0.92, 0.94, 0.97, 1.00],
    'Yield_percent': [62, 66, 70, 73, 78, 81, 84, 68, 71, 76, 80, 83, 86, 88, 72, 77, 81, 85, 87, 90]
})

process_df

# %% [markdown]
# ### Copilot Activity 1 – Features and Target
#
# Ask Copilot:
#
# > I have a chemical process dataset with Temperature_C, Pressure_bar, Reaction_Time_min, Feed_Concentration_mol_L and Yield_percent. Explain which columns should be treated as ML features and which column should be the target if I want to predict yield. Explain why. Do not write code.

# %% [markdown]
# ## 4. Activity 2 – Explore the Dataset
#
# Before training a machine-learning model, inspect the data.
#
# Use Pandas to find:
#
# 1. Number of rows and columns.
# 2. Column names.
# 3. Data types.
# 4. Missing values.
# 5. Basic statistics.
#
# Also create a simple plot showing **Temperature vs Yield**.

# %%
# Activity 2
# Explore the dataset using Pandas and create a Temperature vs Yield plot.

# %% [markdown]
# ### Copilot Activity 2 – Why Explore Data First?
#
# Ask Copilot:
#
# > Explain why a machine-learning workflow should inspect and visualize a chemical process dataset before training a model. Mention missing values, unusual values, variable ranges and possible relationships between inputs and the target.

# %% [markdown]
# ## 5. Activity 3 – Define Features (X) and Target (y)
#
# For our prediction problem:
#
# ### Features (`X`)
#
# - Temperature
# - Pressure
# - Reaction time
# - Feed concentration
#
# ### Target (`y`)
#
# - Yield percentage
#
# Create `X` and `y` using Pandas.

# %%
# Activity 3
# Create X containing the input features and y containing Yield_percent.

# %% [markdown]
# ## 6. Activity 4 – Split Training and Testing Data
#
# A machine-learning model should not be evaluated only on the data used to train it.
#
# Use scikit-learn's `train_test_split()` to divide the data into:
#
# - **training data** – used to learn the relationship,
# - **testing data** – used to evaluate the model on unseen records.
#
# Use a suitable test size and `random_state` so that your result is reproducible.

# %% [markdown]
# ### Copilot Activity 3 – Train/Test Split
#
# Ask Copilot:
#
# > Explain why machine learning uses separate training and testing data. Explain it using the example of predicting chemical-process yield. Do not write the complete Python code.

# %%
# Activity 4
# Import train_test_split and divide X and y into training and testing sets.

# %% [markdown]
# ## 7. Activity 5 – Train a Basic Regression Model
#
# Because `Yield_percent` is a numerical value, this is a **regression** problem.
#
# Use a simple **Linear Regression** model from scikit-learn.
#
# Workflow:
#
# ```text
# Create model
#     ↓
# Fit model using training data
#     ↓
# Predict using test data
# ```
#
# Do not worry about advanced algorithms yet. The objective is to understand the basic ML workflow.

# %%
# Activity 5
# Import LinearRegression, create the model and train it using X_train and y_train.

# %% [markdown]
# ### Copilot Activity 4 – Understand `.fit()` and `.predict()`
#
# Ask Copilot:
#
# > Explain the difference between model.fit() and model.predict() in scikit-learn. Explain them using my chemical-process yield prediction problem. Do not provide a complete program.

# %% [markdown]
# ## 8. Activity 6 – Predict Yield
#
# Use the trained model to predict yield for the testing dataset.
#
# Create a small table containing:
#
# - actual yield,
# - predicted yield.
#
# Compare the values.

# %%
# Activity 6
# Generate predictions and create an actual-vs-predicted DataFrame.

# %% [markdown]
# ## 9. Activity 7 – Evaluate the Model
#
# Use simple regression metrics:
#
# - **MAE – Mean Absolute Error**
# - **RMSE – Root Mean Squared Error**
# - **R² – coefficient of determination**
#
# Use scikit-learn metrics to calculate them.
#
# ### Think
#
# Which metric tells you the typical size of prediction error in the original yield units?
#
# Why should a model's performance be evaluated on test data?

# %% [markdown]
# ### Copilot Activity 5 – Understand Metrics
#
# Ask Copilot:
#
# > Explain MAE, RMSE and R-squared to a second-year chemical engineering student using a yield-prediction example. Explain what a smaller error means and what R-squared is trying to measure. Do not write code.

# %%
# Activity 7
# Calculate MAE, RMSE and R2 for the test predictions.

# %% [markdown]
# ## 10. Activity 8 – Actual vs Predicted Plot
#
# Create a scatter plot comparing:
#
# - actual yield on the x-axis,
# - predicted yield on the y-axis.
#
# Add a reference line representing perfect prediction.
#
# ### Think
#
# If predictions are close to the perfect-prediction line, what does that suggest?

# %%
# Activity 8
# Create an actual-vs-predicted plot.

# %% [markdown]
# ## 11. Activity 9 – Predict Yield for a New Process Condition
#
# Suppose a new process condition is proposed:
#
# - Temperature = 82 °C
# - Pressure = 2.1 bar
# - Reaction time = 29 min
# - Feed concentration = 0.91 mol/L
#
# Use your trained model to predict the expected yield.
#
# ### Important
#
# This is a **model prediction**, not a guarantee of the actual industrial result. A real process decision would require validated data, appropriate process constraints and engineering judgment.

# %%
# Activity 9
# Create one new process-condition record and predict its yield.

# %% [markdown]
# ## 12. Activity 10 – Simple Process Optimization Idea
#
# The syllabus mentions **process optimization and prediction**.
#
# For a simple programming exercise, create several candidate process conditions within the range of the available teaching dataset.
#
# Use the trained model to predict yield for each candidate.
#
# Then identify the candidate with the highest predicted yield.
#
# ### Important distinction
#
# Prediction and optimization are related but not identical:
#
# - **Prediction:** What yield might we expect for a given process condition?
# - **Optimization:** Which allowable process condition gives the best predicted result according to our chosen objective?
#
# Do not search outside the reasonable range of the training data without discussing why that may be unreliable.

# %%
# Activity 10
# Create candidate process conditions, predict yield for each, and identify the best predicted candidate.

# %% [markdown]
# ### Copilot Activity 6 – Prediction vs Optimization
#
# Ask Copilot:
#
# > Explain the difference between prediction and optimization in a chemical process. Use a machine-learning model that predicts yield from temperature, pressure and reaction time as the example. Explain why optimization should respect process constraints and why predictions outside the training range can be unreliable.

# %% [markdown]
# ## 13. Activity 11 – Understand Feature Importance Carefully
#
# Linear regression provides coefficients that can help us understand the fitted relationship.
#
# Inspect the model coefficients and match them with the feature names.
#
# ### Think carefully
#
# Can you simply say that the feature with the largest coefficient is the most important chemical variable?
#
# Discuss:
#
# - units of the features,
# - scale of the variables,
# - direction of the coefficient,
# - correlation between variables,
# - the difference between model association and physical causation.

# %%
# Activity 11
# Display the model coefficients together with their feature names.

# %% [markdown]
# ## 14. Copilot Debugging Challenge
#
# The following code contains a common machine-learning mistake.
#
# Study it **before** asking Copilot.
#
# ```python
# model = LinearRegression()
# model.fit(X_train, y_test)
# ```
#
# ### Your task
#
# 1. Run the code.
# 2. Observe the error.
# 3. Identify why `y_test` is not appropriate when fitting the model with `X_train`.
# 4. Ask Copilot:
#
# > My LinearRegression model is being fitted with X_train and y_test and gives a problem. Explain why the feature rows and target rows must correspond and which target dataset should be used for training. Do not rewrite my complete program.
#
# 5. Correct the code yourself.

# %%
# Run the intentionally incorrect code here after X_train, X_test, y_train and y_test exist.
from sklearn.linear_model import LinearRegression

debug_model = LinearRegression()
debug_model.fit(X_train, y_test)

# %% [markdown]
# ### Explain the error in your own words
#
# Write your explanation here before continuing.

# %% [markdown]
# ## 15. Final Mini-Project – Chemical Process Yield Prediction and Simple Optimization
#
# Build one clean machine-learning workflow using the chemical-process dataset.
#
# Your final workflow must contain:
#
# ### Part A – Data preparation
# 1. Load/create the dataset using Pandas.
# 2. Inspect the data.
# 3. Define features and target.
# 4. Check for missing values.
#
# ### Part B – Machine learning
# 5. Split the data into training and testing sets.
# 6. Train a Linear Regression model.
# 7. Predict the test-set yield.
# 8. Calculate MAE, RMSE and R².
#
# ### Part C – Visualization
# 9. Create an actual-vs-predicted plot.
# 10. Display the model coefficients.
#
# ### Part D – Prediction
# 11. Predict yield for a new process condition.
#
# ### Part E – Simple optimization
# 12. Create several candidate process conditions within the reasonable range of the dataset.
# 13. Predict yield for each candidate.
# 14. Identify the candidate with the highest predicted yield.
# 15. Clearly state that this is a **model-based teaching exercise**, not a validated industrial optimization.

# %%
# FINAL PROJECT
# Chemical Process Yield Prediction and Simple Optimization
# Build your complete ML workflow here.

# %% [markdown]
# ## 16. Final Copilot Review
#
# After completing your final project, ask Copilot:
#
# > Review my beginner machine-learning workflow for chemical process yield prediction. Check my feature/target selection, train-test split, Linear Regression training, prediction, MAE/RMSE/R2 calculations, actual-vs-predicted plot and simple optimization step. Do not rewrite the notebook; identify possible issues and explain them.
#
# Make changes only after you understand the feedback.

# %% [markdown]
# ## 17. Reflection – What Did You Learn?
#
# Answer in your own words:
#
# 1. What is machine learning in simple terms?
# 2. What are features in this chemical-process problem?
# 3. What is the target variable?
# 4. Why do we split data into training and testing sets?
# 5. What does `model.fit()` do?
# 6. What does `model.predict()` do?
# 7. What do MAE, RMSE and R² tell us?
# 8. Why is an actual-vs-predicted plot useful?
# 9. What is the difference between prediction and optimization?
# 10. Why can predictions outside the training range be unreliable?
# 11. Why should a model not automatically be treated as a physical law or causal explanation?
# 12. What did Copilot help you understand or debug?
# 13. Can you explain your complete ML workflow without opening Copilot?

# %% [markdown]
# ## 18. Submission Checklist
#
# - [ ] I created/loaded a chemical-process dataset.
# - [ ] I identified features and target.
# - [ ] I inspected the data and missing values.
# - [ ] I split the dataset into training and testing data.
# - [ ] I trained a Linear Regression model.
# - [ ] I generated predictions.
# - [ ] I calculated MAE, RMSE and R².
# - [ ] I created an actual-vs-predicted plot.
# - [ ] I inspected model coefficients.
# - [ ] I predicted yield for a new process condition.
# - [ ] I performed a simple model-based optimization exercise.
# - [ ] I completed the Copilot debugging challenge.
# - [ ] I wrote my own interpretation of the model results.
# - [ ] I used Copilot for explanation and debugging rather than simply copying a complete solution.
# - [ ] I can explain every major step in the final notebook.
# - [ ] I saved the completed notebook in my GitHub repository.

# %% [markdown]
# ## 19. Suggested Evaluation – Faculty Use
#
# | Component | Marks |
# |---|---:|
# | Data preparation and feature/target selection | 1 |
# | Train-test split | 1 |
# | Linear Regression implementation | 2 |
# | Prediction and evaluation metrics | 2 |
# | Visualization and interpretation | 1 |
# | New-process prediction | 1 |
# | Simple optimization exercise | 1 |
# | Copilot usage, debugging and explanation | 1 |
# | **Total** | **11** |
#
# **Suggested normalization:** Convert the above to 10 marks if required by the laboratory assessment scheme.
#
# **Faculty note:** During evaluation, provide a small new dataset or modify one feature value and ask the student to explain which columns are features and target, train/predict with the model, and interpret one evaluation metric. Ask why the model should not be blindly used outside the range of its training data.
