# %%
print("parth wani")
# Out:
# parth wani

# %%
name = input("Enter your name: ")   
print(f"Hello, {name}!")
# Out:
# Hello, Parth Wani!

# %%
# Student grade A - above 95 marks, B - above 85, C - above 75, D - above 65, F - below 65
# if-elif-else statement
marks = int(input("Enter your marks: "))
if marks > 95:
    print("Grade A")
elif marks > 85:
    print("Grade B")
elif marks > 75:
    print("Grade C")
elif marks > 65:
    print("Grade D")
else:
    print("Grade F")
# Out:
# Grade D
