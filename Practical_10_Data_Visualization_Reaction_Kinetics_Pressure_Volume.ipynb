# %% [markdown]
# # Practical 10: Data Visualization using Python
#
# ### Computer Programming Lab – Chemical Engineering
# **Syllabus Experiment:** **Data visualization (plots of reaction kinetics, pressure vs. volume) using Python libraries like matplotlib**
# **Main Python Library:** `matplotlib`
# **Supporting Library:** `pandas`
# **Environment:** Google Colab / GitHub Codespaces + Jupyter Notebook + GitHub Copilot
#
# ---
#
# ## Important: Exact Syllabus Context
#
# The complete experiment line in the syllabus is:
#
# > **Data visualization (plots of reaction kinetics, pressure vs. volume) using Python libraries like matplotlib**
#
# This practical therefore concentrates on **exactly two chemical-engineering visualization applications**:
#
# 1. **Reaction kinetics plots** – understanding how a reaction variable changes with time.
# 2. **Pressure vs. Volume plots** – visualizing the relationship between pressure and volume.
#
# The main plotting library will be **Matplotlib**, with Pandas used to organize the data.
#
# ## AI Copilot Approach
#
# GitHub Copilot is used as an AI learning assistant. Students will use it to:
#
# - understand Matplotlib commands,
# - choose suitable plotting commands,
# - improve labels and readability,
# - explain errors,
# - debug plotting code,
# - interpret what a graph is showing.
#
# **Do not ask Copilot to generate the complete practical.** Build the plots step by step and use Copilot for explanation, hints and debugging.

# %% [markdown]
# ## 1. Learning Objectives
#
# After completing this practical, you should be able to:
#
# 1. Understand the role of data visualization in chemical engineering.
# 2. Create basic plots using Matplotlib.
# 3. Plot reaction kinetics data against time.
# 4. Compare two reaction kinetics datasets on one graph.
# 5. Plot pressure versus volume data.
# 6. Add title, axis labels, units, legend and grid to engineering plots.
# 7. Select an appropriate plot for a given set of experimental measurements.
# 8. Use Pandas and Matplotlib together.
# 9. Interpret trends from reaction kinetics and pressure-volume plots.
# 10. Use GitHub Copilot to understand and debug visualization code.

# %% [markdown]
# ## 2. Why Data Visualization is Important
#
# Chemical engineers regularly work with experimental and process data. A table may contain many numbers, but a graph can make a relationship or trend much easier to see.
#
# For example:
#
# ### Reaction kinetics
# We may want to observe how concentration changes as reaction time increases.
#
# ### Pressure vs. Volume
# We may want to observe how pressure changes when the volume of a gas changes.
#
# ### Engineering rule
#
# A good plot should help answer a specific engineering question. It should have meaningful labels, units and a clear title.

# %% [markdown]
# ## 3. Activity 1 – Introduction to Matplotlib
#
# Import the required libraries.
#
# Matplotlib provides functions such as:
#
# ```text
# plt.plot()
# plt.scatter()
# plt.xlabel()
# plt.ylabel()
# plt.title()
# plt.legend()
# plt.grid()
# plt.show()
# ```
#
# Before creating an engineering plot, understand what each function does.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Copilot Activity 1 – Understand Matplotlib
#
# Ask Copilot:
#
# > I am a second-year chemical engineering student learning Matplotlib. Explain the purpose of plot(), xlabel(), ylabel(), title(), legend(), grid() and show() using a simple engineering graph example. Do not write the complete program.

# %% [markdown]
# ## 4. Activity 2 – Reaction Kinetics Data
#
# Consider the following **illustrative reaction kinetics data**. It represents the concentration of a reactant measured at different times.
#
# Create a Pandas DataFrame containing:
#
# - `Time_min`
# - `Concentration_mol_L`
#
# These values are provided only for programming and visualization practice.

# %%
kinetics_df = pd.DataFrame({
    'Time_min': [0, 5, 10, 15, 20, 25, 30, 40, 50],
    'Concentration_mol_L': [1.00, 0.88, 0.77, 0.68, 0.60, 0.53, 0.47, 0.37, 0.29]
})

kinetics_df

# %% [markdown]
# ## 5. Activity 3 – Plot Reaction Kinetics
#
# Create a **line plot** of concentration against reaction time.
#
# Use:
#
# - **X-axis:** Time (min)
# - **Y-axis:** Concentration (mol/L)
#
# Your graph must contain:
#
# - suitable title,
# - axis labels,
# - units,
# - grid,
# - appropriate figure size.
#
# ### Think
#
# What happens to the concentration as time increases?

# %%
# Activity 3
# Create the reaction kinetics concentration-versus-time plot.

# %% [markdown]
# ### Copilot Activity 2 – Reaction Kinetics Plot
#
# Ask Copilot:
#
# > Explain why a concentration-versus-time line plot is suitable for visualizing reaction kinetics data. Explain what should be placed on the x-axis and y-axis and why. Do not write my complete plotting code.

# %% [markdown]
# ## 6. Activity 4 – Compare Two Reaction Runs
#
# Suppose the same reaction is performed under a second condition.
#
# Create a second concentration dataset and plot both reaction runs on the **same graph**.
#
# Use a legend such as:
#
# - Run 1
# - Run 2
#
# ### Questions
#
# 1. Which run shows a faster decrease in concentration?
# 2. At 20 minutes, which run has the lower concentration?
# 3. Why is it useful to show both runs on the same graph?

# %%
# Activity 4
# Add a second reaction run and plot both runs together.

# %% [markdown]
# ### Copilot Activity 3 – Multiple Curves
#
# Ask Copilot:
#
# > Explain how to plot two reaction kinetics datasets on the same Matplotlib axes and distinguish them using a legend. Explain the idea without giving the complete code.

# %% [markdown]
# ## 7. Activity 5 – Pressure vs. Volume Data
#
# Now work with the second application explicitly mentioned in the syllabus: **pressure vs. volume**.
#
# Consider this simplified teaching dataset for a gas system:
#
# - `Volume_L`
# - `Pressure_bar`
#
# The values are illustrative and are intended only to demonstrate data visualization.

# %%
pv_df = pd.DataFrame({
    'Volume_L': [1.0, 1.2, 1.5, 1.8, 2.0, 2.5, 3.0, 3.5, 4.0],
    'Pressure_bar': [4.00, 3.34, 2.68, 2.23, 2.02, 1.62, 1.35, 1.15, 1.01]
})

pv_df

# %% [markdown]
# ## 8. Activity 6 – Plot Pressure vs. Volume
#
# Create a graph with:
#
# - **X-axis:** Volume (L)
# - **Y-axis:** Pressure (bar)
#
# Use a suitable plot for the data.
#
# Include:
#
# - title,
# - axis labels,
# - units,
# - grid,
# - appropriate figure size.
#
# ### Think
#
# Does pressure increase or decrease as volume increases?

# %%
# Activity 6
# Create the pressure-versus-volume plot.

# %% [markdown]
# ### Copilot Activity 4 – Pressure vs. Volume
#
# Ask Copilot:
#
# > Explain why volume should be placed on the x-axis and pressure on the y-axis for a pressure-versus-volume engineering plot. Explain what trend I should look for without calculating the result for me.

# %% [markdown]
# ## 9. Activity 7 – Line Plot vs Scatter Plot
#
# Create the pressure-volume graph again using a **scatter plot**.
#
# Compare the line plot and scatter plot.
#
# ### Think
#
# Which representation makes the individual measurements more visible?
#
# Which representation makes the overall relationship easier to follow?

# %%
# Activity 7
# Create a scatter plot for the pressure-volume measurements.

# %% [markdown]
# ## 10. Activity 8 – Add a Reference Relationship
#
# For an idealized constant-temperature gas relationship, pressure and volume are inversely related.
#
# Create a simple reference curve using a constant `k`:
#
# ```text
# P = k / V
# ```
#
# Use the experimental/teaching pressure-volume points and plot the reference relationship on the same graph.
#
# ### Important
#
# The purpose here is to learn how to compare measured points with a simple mathematical relationship. Do not claim that real experimental data must exactly follow the idealized relationship.

# %%
# Activity 8
# Plot the pressure-volume data together with a simple P = k/V reference curve.

# %% [markdown]
# ### Copilot Activity 5 – Reference Curves
#
# Ask Copilot:
#
# > Explain how a reference mathematical curve can be plotted together with experimental pressure-volume data. Explain why the measured points and reference curve should be clearly distinguished. Do not write the complete code.

# %% [markdown]
# ## 11. Activity 9 – Improve the Engineering Plot
#
# Take your pressure-volume plot and improve its presentation.
#
# Check all of the following:
#
# - Is the title meaningful?
# - Are both axis names present?
# - Are units shown?
# - Is the legend understandable?
# - Is the grid useful?
# - Is the figure large enough?
# - Can another student understand the graph without seeing your code?
#
# ### Engineering communication principle
#
# A graph is part of technical communication. A technically correct graph can still be poor if the reader cannot understand it quickly.

# %%
# Activity 9
# Redraw your pressure-volume graph with improved presentation.

# %% [markdown]
# ## 12. Activity 10 – Visualize Both Applications
#
# Create two final plots in separate cells:
#
# ### Plot A
# Reaction kinetics: **Concentration vs. Time**
#
# ### Plot B
# Gas/process data: **Pressure vs. Volume**
#
# For each plot, write 2–3 sentences explaining the trend visible in the graph.

# %%
# Activity 10A
# Final reaction kinetics plot.

# %%
# Activity 10B
# Final pressure-versus-volume plot.

# %% [markdown]
# ## 13. Copilot Debugging Challenge
#
# The following code contains a common Matplotlib mistake.
#
# Study it **before** asking Copilot.
#
# ```python
# plt.plot(pv_df['Volume_L'], pv_df['Pressure_bar'])
# plt.xlabel('Volume (L)')
# plt.ylabel('Pressure (bar)')
# plt.title('Pressure vs Volume')
# plt.show
# ```
#
# ### Your task
#
# 1. Run the code.
# 2. Observe the behavior.
# 3. Identify the problem.
# 4. Ask Copilot:
#
# > My Matplotlib graph code contains plt.show but the graph is not being displayed as expected. Explain what is wrong and why parentheses are required. Do not rewrite the complete code.
#
# 5. Correct the code yourself.
#
# ### Second debugging challenge
#
# Now deliberately swap the x and y columns in your pressure-volume plot. Ask yourself whether the graph still represents **pressure vs. volume** correctly. Use Copilot only after you have identified the problem.

# %%
# Run the intentionally incorrect code here.
plt.plot(pv_df['Volume_L'], pv_df['Pressure_bar'])
plt.xlabel('Volume (L)')
plt.ylabel('Pressure (bar)')
plt.title('Pressure vs Volume')
plt.show

# %% [markdown]
# ### Explain the error in your own words
#
# Write your explanation here before continuing.

# %% [markdown]
# ## 14. Final Mini-Project – Chemical Engineering Visualization Report
#
# Create a small visualization report containing the **two applications specified in the syllabus**.
#
# ### Part A – Reaction Kinetics
#
# 1. Use a reaction kinetics dataset.
# 2. Plot concentration versus time.
# 3. Compare two reaction runs or conditions.
# 4. Add proper title, labels, units, legend and grid.
# 5. Write a short interpretation of the trend.
#
# ### Part B – Pressure vs. Volume
#
# 1. Use a pressure-volume dataset.
# 2. Plot pressure versus volume.
# 3. Use a scatter or line representation as appropriate.
# 4. Optionally compare the observations with a simple reference relationship.
# 5. Add proper title, labels, units, legend and grid.
# 6. Write a short interpretation of the trend.
#
# ### AI requirement
#
# Use Copilot at least three times:
#
# - once for understanding Matplotlib,
# - once for improving or debugging a graph,
# - once for explaining a plotting/engineering interpretation.
#
# Record briefly what Copilot suggested and what you changed.

# %%
# FINAL PROJECT
# Chemical Engineering Visualization Report
# Create your reaction kinetics and pressure-volume plots here.

# %% [markdown]
# ## 15. Final Copilot Review
#
# After completing your final project, ask Copilot:
#
# > Review my Matplotlib visualization notebook for chemical engineering data. Check my reaction kinetics and pressure-versus-volume plots for correct x/y variables, labels, units, legends, titles and readability. Do not rewrite the notebook; identify possible issues and explain them.
#
# Make corrections only after you understand the feedback.

# %% [markdown]
# ## 16. Reflection – What Did You Learn?
#
# Answer in your own words:
#
# 1. Why is data visualization useful in chemical engineering?
# 2. What should be plotted on the x-axis for a concentration-versus-time reaction kinetics graph?
# 3. What does the concentration-time graph tell you?
# 4. Why can two reaction runs be plotted on the same axes?
# 5. What should be on the x-axis and y-axis of a pressure-versus-volume graph?
# 6. What trend do you observe in the pressure-volume data?
# 7. What is the difference between a line plot and a scatter plot?
# 8. Why are units important on engineering graphs?
# 9. What was the Matplotlib error in the debugging challenge?
# 10. What did Copilot help you understand or debug?
# 11. Can you create a correctly labelled engineering plot without asking Copilot?

# %% [markdown]
# ## 17. Submission Checklist
#
# - [ ] I imported Matplotlib and Pandas.
# - [ ] I created reaction kinetics data.
# - [ ] I plotted concentration versus time.
# - [ ] I compared two reaction runs.
# - [ ] I created pressure-volume data.
# - [ ] I plotted pressure versus volume.
# - [ ] I tried both line and scatter representation where appropriate.
# - [ ] I added a reference P = k/V relationship.
# - [ ] I used correct x/y variables.
# - [ ] I added titles, labels and units.
# - [ ] I completed the Copilot debugging challenge.
# - [ ] I completed the final two-part visualization project.
# - [ ] I wrote engineering interpretations for both plots.
# - [ ] I used Copilot for explanation and debugging rather than simply copying a complete solution.
# - [ ] I can explain my graphs without opening Copilot.
# - [ ] I saved the completed notebook in my GitHub repository.

# %% [markdown]
# ## 18. Suggested Evaluation – Faculty Use
#
# | Component | Marks |
# |---|---:|
# | Reaction kinetics plot | 2 |
# | Comparison of reaction runs | 1 |
# | Pressure vs. volume plot | 2 |
# | Correct use of Matplotlib/Pandas | 1 |
# | Plot titles, labels, units and legends | 1 |
# | Engineering interpretation | 1 |
# | Copilot usage and debugging | 1 |
# | Student's ability to explain/modify the plot | 1 |
# | **Total** | **10** |
#
# **Faculty note:** During evaluation, provide a small new dataset and ask the student to create either a concentration-versus-time plot or pressure-versus-volume plot, choose the correct x/y variables, add units and explain one visible trend.
